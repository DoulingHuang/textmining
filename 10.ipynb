# %%
import pandas as pd

# %%
data=pd.read_csv(r'desk2.csv',header=0).T
data
# Out:
#                                                        0        1      2    \
# Unnamed: 0                                          smooth  vanilla  smoke
# Old Pulteney 21 Year Old                                 4        2      2
# Glenkinchie 12 Year Old                                 94        4     10
# Unnamed: 3                                             NaN      NaN    NaN
# hat mor"                                               NaN      NaN    NaN
# ...                                                    ...      ...    ...
# Old Forester Bourbon                                     8        4    NaN
# Writers Tears Cask Strength 2017 Release                 2      NaN    NaN
# Hakushu The Hakushu Single Malt Whisky Distille...       3        2      1
# Wyoming Whiskey Barrel Strength                        NaN        1      1
# Knob Creek 2018 Hero's Share Knob Creek 13 Year...       1      NaN    NaN
#
# ...

# %%
data.to_csv('New_Data.csv',encoding='utf8')
